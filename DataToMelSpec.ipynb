# %%
import os
import shutil
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %%
Emotions = ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness','surprise']

for e in Emotions :
    path = "/content/drive/MyDrive/Project/VisualData/" + e
    os.mkdir(path)

# %%
n_fft = 2048
hop_length = 512
n_mels = 128

# %%
# Storing the Mel-Spectrogram of all the emotions

# %%
dirs = os.listdir("/content/drive/MyDrive/Project/Dataset")

for d in dirs :

    src = "/content/drive/MyDrive/Project/Dataset/" + d + '/'
    dest = "/content/drive/MyDrive/Project/VisualData/" + d + '/'
    files = os.listdir("/content/drive/MyDrive/Project/Dataset/" + d)

    for f in files :
        y, sr = librosa.load(src + f)
        emotion, _ = librosa.effects.trim(y)
        S = librosa.feature.melspectrogram(emotion, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
        S_DB = librosa.power_to_db(S, ref=np.max)
        librosa.display.specshow(S_DB, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel');
        plt.colorbar(format='%+2.0f dB');
        plt.savefig(dest + f[:-4] + '.png')
        plt.clf()
